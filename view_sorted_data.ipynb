# %%
import pandas as pd

df_meta = pd.read_csv('data/medical-diff-vqa-1.0.1/mimic_all_sorted.csv')
df_meta.head(10000)
# Out:
#       subject_id  study_id  Atelectasis  Cardiomegaly  Consolidation  Edema  \
# 0       10000032  50414267          NaN           NaN            NaN    NaN
# 1       10000032  53189527          NaN           NaN            NaN    NaN
# 2       10000032  53911762          NaN           NaN            NaN    NaN
# 3       10000032  56699142          NaN           NaN            NaN    NaN
# 4       10000764  57375967          NaN           NaN            1.0    NaN
# ...          ...       ...          ...           ...            ...    ...
# 9995    10445927  54715030          NaN           1.0            NaN    1.0
# 9996    10446159  54258203          NaN           NaN            NaN    NaN
# 9997    10446182  53368873          NaN           NaN            NaN    NaN
# 9998    10446182  53047574          NaN           NaN            NaN    NaN
# 9999    10446182  58107350          NaN           NaN            NaN    NaN
#
# ...

# %%
df_vqa = pd.read_csv('data/medical-diff-vqa-1.0.1/mimic_pair_sorted.csv')
df_vqa.head(10000)
# Out:
#       study_id  subject_id    ref_id question_type  \
# 0     50414267    10000032  53911762   abnormality
# 1     50414267    10000032  53911762      presence
# 2     50414267    10000032  53911762          view
# 3     50414267    10000032  53911762      location
# 4     53189527    10000032  56699142   abnormality
# ...        ...         ...       ...           ...
# 9995  50384416    10152121  58419790    difference
# 9996  51932239    10152121  58219738   abnormality
# 9997  51932239    10152121  58219738      presence
# 9998  51932239    10152121  58219738         level
# 9999  51932239    10152121  58219738          type
#
#                                                question  \
# 0            what abnormalities are seen in this image?
# 1                                is there lung opacity?
# 2                                      is this AP view?
# 3                            where is the lung opacity?
# 4            what abnormalities are seen in this image?
# ...
