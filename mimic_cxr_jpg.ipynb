# %%
import pandas as pd

# %%
df_pair_question = pd.read_csv('data/medical-diff-vqa-1.0.1/mimic_pair_questions.csv')
df_pair_question.head(10)
# Out:
#    study_id  subject_id    ref_id question_type  \
# 0  55088298    18936629  54989200   abnormality
# 1  55088298    18936629  54989200      presence
# 2  55088298    18936629  54989200      location
# 3  55088298    18936629  54989200         level
# 4  55088298    18936629  54989200    difference
# 5  51480826    18936629  50632107   abnormality
# 6  51480826    18936629  50632107      presence
# 7  51480826    18936629  50632107      location
# 8  51480826    18936629  50632107         level
# 9  50632107    18936629  51480826    difference
#
#                                             question  \
# 0   what abnormalities are seen in the soft tissues?
# 1                                    is there edema?
# 2  is the atelectasis located on the left side or...
# 3                    what level is the pneumothorax?
# 4  what has changed compared to the reference image?
# 5         what abnormalities are seen in this image?
# 6    is there pneumothorax in the right apical area?
# ...

# %%
df_chexpert = pd.read_csv('data/mimic-cxr-jpg-2.1.0/mimic-cxr-2.0.0-chexpert.csv')
df_chexpert.head(10)
# Out:
#    subject_id  study_id  Atelectasis  Cardiomegaly  Consolidation  Edema  \
# 0    10000032  50414267          NaN           NaN            NaN    NaN
# 1    10000032  53189527          NaN           NaN            NaN    NaN
# 2    10000032  53911762          NaN           NaN            NaN    NaN
# 3    10000032  56699142          NaN           NaN            NaN    NaN
# 4    10000764  57375967          NaN           NaN            1.0    NaN
# 5    10000898  50771383          NaN           NaN            NaN    NaN
# 6    10000898  54205396          NaN           NaN            NaN    NaN
# 7    10000935  50578979          NaN           NaN            NaN   -1.0
# 8    10000935  51178377          NaN           NaN            NaN    NaN
# 9    10000935  55697293          NaN           NaN            NaN    NaN
#
#    Enlarged Cardiomediastinum  Fracture  Lung Lesion  Lung Opacity  \
# 0                         NaN       NaN          NaN           NaN
# ...

# %%
df_metadata = pd.read_csv('data/mimic-cxr-jpg-2.1.0/mimic-cxr-2.0.0-metadata.csv')
df_metadata.head(10)
# Out:
#                                        dicom_id  subject_id  study_id  \
# 0  02aa804e-bde0afdd-112c0b34-7bc16630-4e384014    10000032  50414267
# 1  174413ec-4ec4c1f7-34ea26b7-c5f994f8-79ef1962    10000032  50414267
# 2  2a2277a9-b0ded155-c0de8eb9-c124d10e-82c5caab    10000032  53189527
# 3  e084de3b-be89b11e-20fe3f9f-9c8d8dfe-4cfd202c    10000032  53189527
# 4  68b5c4b1-227d0485-9cc38c3f-7b84ab51-4b472714    10000032  53911762
# 5  fffabebf-74fd3a1f-673b6b41-96ec0ac9-2ab69818    10000032  53911762
# 6  ea030e7a-2e3b1346-bc518786-7a8fd698-f673b44c    10000032  56699142
# 7  096052b7-d256dc40-453a102b-fa7d01c6-1b22c6b4    10000764  57375967
# 8  b79e55c3-735ce5ac-64412506-cdc9ea79-f1af521f    10000764  57375967
# 9  dcfeeac4-1597e318-d0e6736a-8b2c2238-47ac3f1b    10000764  57375967
#
#   PerformedProcedureStepDescription ViewPosition  Rows  Columns  StudyDate  \
# 0                CHEST (PA AND LAT)           PA  3056     2544   21800506
# ...

# %%
df_negbio = pd.read_csv('data/mimic-cxr-jpg-2.1.0/mimic-cxr-2.0.0-negbio.csv')
df_negbio
# Out:
#         subject_id  study_id  Atelectasis  Cardiomegaly  Consolidation  Edema  \
# 0         10000032  50414267          NaN           NaN            NaN    NaN
# 1         10000032  53189527          NaN           NaN            NaN    NaN
# 2         10000032  53911762          NaN           NaN            NaN    NaN
# 3         10000032  56699142          NaN           NaN            NaN    NaN
# 4         10000764  57375967          NaN           NaN            1.0    NaN
# ...            ...       ...          ...           ...            ...    ...
# 227822    19999442  58708861          NaN           NaN            NaN    NaN
# 227823    19999733  57132437          NaN           NaN            NaN    NaN
# 227824    19999987  55368167          1.0          -1.0            NaN    NaN
# 227825    19999987  58621812          1.0           NaN            NaN    NaN
# 227826    19999987  58971208          1.0           NaN            NaN    NaN
#
# ...

# %%
df_split = pd.read_csv('data/mimic-cxr-jpg-2.1.0/mimic-cxr-2.0.0-split.csv')
df_split
# Out:
#                                             dicom_id  study_id  subject_id  \
# 0       02aa804e-bde0afdd-112c0b34-7bc16630-4e384014  50414267    10000032
# 1       174413ec-4ec4c1f7-34ea26b7-c5f994f8-79ef1962  50414267    10000032
# 2       2a2277a9-b0ded155-c0de8eb9-c124d10e-82c5caab  53189527    10000032
# 3       e084de3b-be89b11e-20fe3f9f-9c8d8dfe-4cfd202c  53189527    10000032
# 4       68b5c4b1-227d0485-9cc38c3f-7b84ab51-4b472714  53911762    10000032
# ...                                              ...       ...         ...
# 377105  428e2c18-5721d8f3-35a05001-36f3d080-9053b83c  57132437    19999733
# 377106  58c403aa-35ff8bd9-73e39f54-8dc9cc5d-e0ec3fa9  57132437    19999733
# 377107  58766883-376a15ce-3b323a28-6af950a0-16b793bd  55368167    19999987
# 377108  7ba273af-3d290f8d-e28d0ab4-484b7a86-7fc12b08  58621812    19999987
# 377109  1a1fe7e3-cbac5d93-b339aeda-86bb86b5-4f31e82e  58971208    19999987
#
#         split
# 0       train
# 1       train
# 2       train
# ...
