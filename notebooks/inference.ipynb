# %%
# %env PYTHONUNBUFFERED=1

import os
from pathlib import Path

if Path.cwd().name == 'notebooks':
    os.chdir('..')
    print(f"Changed working directory to: {Path.cwd()}")
# Out:
# env: PYTHONUNBUFFERED=1
# Changed working directory to: c:\Users\neucl\Dev\Thesis\cxr-diff-vqa

# %%
from src.inference import main
import argparse

args = argparse.Namespace()

args.config = 'configs/clinicalbert_resnet.yaml'
args.model_path = 'models/drift_vqa_final.pth'
args.ref_image = 'D:/MIMIC-CXR-JPG/p10/p10000935/s56522600/f1adcae3-2921c0a8-5d9652f9-4191ecd7-f2a96f35.jpg' 
args.cur_image = 'D:/MIMIC-CXR-JPG/p10/p10000935/s55697293/c50494f1-90e2bff5-e9189550-1a4562fd-6ab5204c.jpg'
args.question = 'what has changed in the left lung?'

main(args)
# Out:
# 2025-11-06 11:49:55,841 - root - INFO - Using device: cuda
# 2025-11-06 11:49:55,841 - root - INFO - Loaded configuration from configs/clinicalbert_resnet.yaml
# 2025-11-06 11:49:55,858 - root - INFO - Vocabulary loaded. Size: 39
# 2025-11-06 11:49:55,858 - lib.model.vqa - INFO - Initializing DiffVQAModel (Decoder-Only) with backbone: resnet18
# 2025-11-06 11:49:56,008 - lib.model.vqa - INFO - DRS output channels: 512, Total visual dim: 2048
# 2025-11-06 11:49:56,008 - lib.model.vqa - INFO - Using TinyText text encoder.
# 2025-11-06 11:49:56,541 - lib.model.vqa - INFO - Initializing Decoder Head. Vocab size: 39, Max len: 8
# 2025-11-06 11:49:57,907 - root - INFO - Loading trained model from: models/drift_vqa_final.pth
# 2025-11-06 11:49:58,891 - root - INFO - Model loaded and set to evaluation mode.
# c:\Users\neucl\Dev\Thesis\cxr-diff-vqa\cxr-env\Lib\site-packages\torch\nn\functional.py:5504: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at ..\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   attn_output = scaled_dot_product_attention(q, k, v, attn_mask, dropout_p, is_causal)
# --- Inference Results ---
# Question: what has changed in the left lung?
# Predicted Answer:
#
# Visualizing directional heatmaps...
