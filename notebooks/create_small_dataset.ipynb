# %%
import pandas as pd

filter_string = '10'

df_pair_qa = pd.read_csv('../data/medical-diff-vqa-1.0.1/mimic_pair_questions.csv')
df_pair_qa.shape
# Out:
# (700703, 7)

# %%
df_pair_qa.head(10)
# Out:
#    study_id  subject_id    ref_id question_type  \
# 0  55088298    18936629  54989200   abnormality
# 1  55088298    18936629  54989200      presence
# 2  55088298    18936629  54989200      location
# 3  55088298    18936629  54989200         level
# 4  55088298    18936629  54989200    difference
# 5  51480826    18936629  50632107   abnormality
# 6  51480826    18936629  50632107      presence
# 7  51480826    18936629  50632107      location
# 8  51480826    18936629  50632107         level
# 9  50632107    18936629  51480826    difference
#
#                                             question  \
# 0   what abnormalities are seen in the soft tissues?
# 1                                    is there edema?
# 2  is the atelectasis located on the left side or...
# 3                    what level is the pneumothorax?
# 4  what has changed compared to the reference image?
# 5         what abnormalities are seen in this image?
# 6    is there pneumothorax in the right apical area?
# ...

# %%
df_pair_qa.dtypes
# Out:
# study_id          int64
# subject_id        int64
# ref_id            int64
# question_type    object
# question         object
# answer           object
# split            object
# dtype: object

# %%
df_small_pair_qa = df_pair_qa[df_pair_qa['subject_id'].astype(str).str.startswith(filter_string)]
df_small_pair_qa.head(10)
# Out:
#         study_id  subject_id    ref_id question_type  \
# 490765  54875791    10765488  50651250   abnormality
# 490766  54875791    10765488  50651250      presence
# 490767  54875791    10765488  50651250          view
# 490768  54875791    10765488  50651250      location
# 490769  54875791    10765488  50651250         level
# 490770  54875791    10765488  50651250          type
# 490771  50651250    10765488  54875791    difference
# 490772  58422555    10765488  53191964   abnormality
# 490773  58422555    10765488  53191964      presence
# 490774  58422555    10765488  53191964      location
#
#                                                  question  \
# 490765         what abnormalities are seen in this image?
# 490766  is there evidence of pleural effusion in this ...
# 490767                    which view is this image taken?
# 490768                     where is the pleural effusion?
# 490769                           what level is the edema?
# ...

# %%
df_small_pair_qa.shape
# Out:
# (67955, 7)

# %%
df_all = pd.read_csv('../data/medical-diff-vqa-1.0.1/mimic_all.csv')
df_all.shape
# Out:
# (227827, 21)

# %%
df_all.head(10)
# Out:
#    subject_id  study_id  Atelectasis  Cardiomegaly  Consolidation  Edema  \
# 0    10000032  50414267          NaN           NaN            NaN    NaN
# 1    10000032  53189527          NaN           NaN            NaN    NaN
# 2    10000032  53911762          NaN           NaN            NaN    NaN
# 3    10000032  56699142          NaN           NaN            NaN    NaN
# 4    10000764  57375967          NaN           NaN            1.0    NaN
# 5    10000898  50771383          NaN           NaN            NaN    NaN
# 6    10000898  54205396          NaN           NaN            NaN    NaN
# 7    10000935  50578979          NaN           NaN            NaN   -1.0
# 8    10000935  51178377          NaN           NaN            NaN    NaN
# 9    10000935  55697293          NaN           NaN            NaN    NaN
#
#    Enlarged Cardiomediastinum  Fracture  Lung Lesion  Lung Opacity  ...  \
# 0                         NaN       NaN          NaN           NaN  ...
# ...

# %%
df_all.dtypes
# Out:
# subject_id                      int64
# study_id                        int64
# Atelectasis                   float64
# Cardiomegaly                  float64
# Consolidation                 float64
# Edema                         float64
# Enlarged Cardiomediastinum    float64
# Fracture                      float64
# Lung Lesion                   float64
# Lung Opacity                  float64
# No Finding                    float64
# Pleural Effusion              float64
# Pleural Other                 float64
# Pneumonia                     float64
# Pneumothorax                  float64
# Support Devices               float64
# dicom_id                       object
# view                           object
# split                          object
# study_date                      int64
# study_order                   float64
# dtype: object

# %%
df_small_all = df_all[df_all['subject_id'].astype(str).str.startswith(filter_string)]
df_small_all.head(10)
# Out:
#    subject_id  study_id  Atelectasis  Cardiomegaly  Consolidation  Edema  \
# 0    10000032  50414267          NaN           NaN            NaN    NaN
# 1    10000032  53189527          NaN           NaN            NaN    NaN
# 2    10000032  53911762          NaN           NaN            NaN    NaN
# 3    10000032  56699142          NaN           NaN            NaN    NaN
# 4    10000764  57375967          NaN           NaN            1.0    NaN
# 5    10000898  50771383          NaN           NaN            NaN    NaN
# 6    10000898  54205396          NaN           NaN            NaN    NaN
# 7    10000935  50578979          NaN           NaN            NaN   -1.0
# 8    10000935  51178377          NaN           NaN            NaN    NaN
# 9    10000935  55697293          NaN           NaN            NaN    NaN
#
#    Enlarged Cardiomediastinum  Fracture  Lung Lesion  Lung Opacity  ...  \
# 0                         NaN       NaN          NaN           NaN  ...
# ...

# %%
df_small_all.shape
# Out:
# (22197, 21)

# %%
df_small_pair_qa.to_csv(f'../data/medical-diff-vqa-1.0.1/mimic_pair_questions_p{filter_string}.csv', index=False)

# %%
df_small_all.to_csv(f'../data/medical-diff-vqa-1.0.1/mimic_all_p{filter_string}.csv', index=False)
